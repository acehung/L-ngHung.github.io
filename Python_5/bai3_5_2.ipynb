# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 6,7]
y = [1, 4, 9, 16, 36,49]
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('y = x^2')
plt.show()

# %%
even = [x for x in range(1,101) if x % 3 == 0 and x % 5 == 0]
print(even)
# Out:
# [15, 30, 45, 60, 75, 90]

# %%
square_gen = (x for x in range(2, 21) if x % 1 == 0)
print(next(square_gen))
print(next(square_gen))
print(next(square_gen))
print(next(square_gen))
print(next(square_gen))
# Out:
# 2
# 3
# 4
# 5
# 6
